# %% [markdown]
# # Data collection and cleaning
#
# This is where we collect and clean our dataset.

# %%
import pandas as pd
import numpy as np

# %%
users = pd.read_csv("data/users.csv")

top_artists = pd.read_csv("data/user_top_artists.csv")
top_tracks = pd.read_csv("data/user_top_tracks.csv")
top_albums = pd.read_csv("data/user_top_albums.csv")

# %%
print("Users table\n")
print(users.head())

print("\nUsers top artists' table\n")
print(top_artists.head())

print("\nUsers top tracks' table\n")
print(top_tracks.head())

print("\nUsers top albums' table\n")
print(top_albums.head())
# Out:
# Users table
#
#    user_id         country  total_scrobbles
# 0        1   United States           204985
# 1        2          France           211013
# 2        3           Spain           244871
# 3        4          Israel            69401
# 4        5  United Kingdom            95449
#
# Users top artists' table
#
#    user_id  rank       artist_name  playcount  \
# 0        1     1   Crystal Castles       1034
# 1        1     2         Radiohead        972
# 2        1     3          Ladytron        831
# 3        1     4  Ghostface Killah        801
# 4        1     5             UNKLE        722
#
#                                    mbid
# 0  b1570544-93ab-4b2b-8398-131735394202
# 1  a74b1b7f-71a5-4011-9441-d0b5e4122711
# 2  b45335d1-5219-4262-a44d-936aa36eeaed
# 3  3b39abeb-0064-4eed-9ddd-ee47a45c54cb
# 4  6648391e-7890-4f6c-b939-976f215195d3
#
# Users top tracks' table
#
#    user_id  rank               track_name          artist_name  playcount  \
# 0        1     1                Ice Cream  New Young Pony Club         54
# 1        1     2  Hiding On The Staircase  New Young Pony Club         51
# 2        1     3                  Descend  New Young Pony Club         49
# 3        1     4                  Air War      Crystal Castles         48
# 4        1     5                Get Lucky  New Young Pony Club         48
#
#                                    mbid
# 0  417a3d0b-0291-4e08-b167-50971dbdae36
# 1  f6ac2fd2-b33b-48ff-a094-537cf530cf20
# 2  33434fd1-79a1-3882-bb31-fbd430815a93
# 3  06d3fea3-e806-35ed-9562-aa396a97de14
# 4  ab351b25-7126-3792-9b0d-ce44fd0c0462
#
# Users top albums' table
#
#    user_id  rank               album_name       artist_name  playcount  \
# 0        1     1                  Visions            Grimes        243
# 1        1     2  Only Built 4 Cuban Linx           Raekwon        240
# 2        1     3    Tales From the Pantry  Lederhosen Lucil        204
# 3        1     4          Crystal Castles   Crystal Castles        200
# 4        1     5                Klanguage         Klanguage        184
#
#                                    mbid
# 0  0136a543-33fa-4b80-a8ca-4a6094db3b71
# 1  c49af812-cb43-45ca-81e6-b81b7c287624
# 2  1f195540-653f-4db4-bb74-e7d215de9bae
# 3  101f993f-d5e1-3f14-b40b-71850f1f435a
# 4  e82aa7a2-9d34-431f-9199-c8eba2df0261

# %%
users = users[users["total_scrobbles"] > 150000].copy()
users = users[users["country"] == "United States"]
top_user_ids = set(users["user_id"])

top_artists = top_artists[top_artists["user_id"].isin(top_user_ids)]
top_tracks = top_tracks[top_tracks["user_id"].isin(top_user_ids)]
top_albums = top_albums[top_albums["user_id"].isin(top_user_ids)]

# %%
len(users)
# Out:
# 14411

# %%
users = users.drop_duplicates(subset="user_id")
top_artists = top_artists.drop_duplicates(subset=["user_id", "artist_name"])
top_tracks = top_tracks.drop_duplicates(subset=["user_id", "track_name"])
top_albums = top_albums.drop_duplicates(subset=["user_id", "album_name"])

# %%
def clean_text(text):
    if pd.isna(text):
        return ""
    return text.strip().lower()

for df, cols in [
    (top_artists, ["artist_name"]),
    (top_tracks, ["artist_name", "track_name"]),
    (top_albums, ["artist_name", "album_name"])
]:
    for col in cols:
        df[col] = df[col].apply(clean_text)

# Replace empty mbid with NaN
for df in [top_artists, top_tracks, top_albums]:
    df["mbid"] = df["mbid"].replace("", pd.NA)

# %%
# Normalize playcount per user (so they sum to 1)
def normalize_playcount(df, group_col="user_id"):
    df["playcount_norm"] = df["playcount"] / df.groupby(group_col)["playcount"].transform("sum")
    return df

top_artists = normalize_playcount(top_artists)
top_tracks = normalize_playcount(top_tracks)
top_albums = normalize_playcount(top_albums)

# Merge with users table
top_artists = top_artists.merge(users, on="user_id", how="left")
top_tracks = top_tracks.merge(users, on="user_id", how="left")
top_albums = top_albums.merge(users, on="user_id", how="left")

# %%
spotify = pd.read_csv("data/spotify_dataset.csv")

spotify["song"] = spotify["song"].apply(clean_text)
spotify["Artist(s)"] = spotify["Artist(s)"].apply(clean_text)

# %%
spotify
# Out:
#                Artist(s)                                               song  \
# 0                    !!!                          even when the waters cold
# 1                    !!!                                 one girl / one boy
# 2                    !!!                                  pardon my freedom
# 3                    !!!                                                ooo
# 4                    !!!                                         freedom 15
# ...                  ...                                                ...
# 551438  박혜진 park hye jin                                            can you
# 551439  심형진 hyungjin sim  lim han byul  lee hyuk - prayer english transl...
# 551440               우정하                       memories smiling tears remix
# 551441                제노                                    come back to me
# 551442                코케                                i wanna be with you
#
#                                                      text Length  emotion  \
# 0       Friends told her she was better off at the bot...  03:47  sadness
# 1       Well I heard it, playing soft From a drunken b...  04:03  sadness
# 2       Oh my god, did I just say that out loud? Shoul...  05:51      joy
# 3       [Verse 1] Remember when I called you on the te...  03:44      joy
# 4       [Verse 1] Calling me like I got something to s...  06:00      joy
# ...                                                   ...    ...      ...
# 551438  Can you be my (Can you be my) Can you be my (C...  03:39      joy
# 551439  [Verse] I gave you my everything But I see I c...  08:47      joy
# 551440  [Tasha]               Hell on earth, watching ...  03:53  sadness
# 551441  [Verse] Gifts and flowers lay upon the lid Of ...  03:12  sadness
# 551442  I wanna b with you I wanna b with you baby Yea...  03:32     love
#
#             Genre                                              Album  \
# 0         hip hop                                           Thr!!!er
# 1         hip hop                                           Thr!!!er
# 2         hip hop                                      Louden Up Now
# 3         hip hop                                              As If
# 4         hip hop                                              As If
# ...           ...                                                ...
# 551438      house                   Can you (Galcher Lustwerk Remix)
# 551439  metalcore                                  비 준비하시니 Psalm_147
# 551440    hip hop                                             MEMORY
# 551441    hip hop                                   2008 to me again
# 551442    hip hop  I Wanna Be With You : Originally Performed By ...
#
#              Release Date     Key  Tempo  ... Good for Morning Routine  \
# 0         29th April 2013   D min    105  ...                        0
# 1         29th April 2013  A# min    117  ...                        0
#         playcount                                  mbid  playcount_norm  \
# 0              54  417a3d0b-0291-4e08-b167-50971dbdae36        0.034177
# 1              51  f6ac2fd2-b33b-48ff-a094-537cf530cf20        0.032278
# 2              49  33434fd1-79a1-3882-bb31-fbd430815a93        0.031013
# 3              48  06d3fea3-e806-35ed-9562-aa396a97de14        0.030380
# 4              48  ab351b25-7126-3792-9b0d-ce44fd0c0462        0.030380
# ...           ...                                   ...             ...
# 719097         48                                   NaN        0.017461
# 719098         48                                   NaN        0.017461
# 719099         48                                   NaN        0.017461
# 719100         48  a93c0566-1f6b-3623-a54c-f0fca49ce85b        0.017461
# 719101         48  536a164c-641b-3490-9411-e66b80cc71db        0.017461
#
#               country  total_scrobbles
# 0       United States           204985
# 1       United States           204985
# 2       United States           204985
# 3       United States           204985
# 4       United States           204985
# ...               ...              ...
# 719097  United States           377013
# 719098  United States           377013
# 719099  United States           377013
# 719100  United States           377013
# 719101  United States           377013
#
# [719102 rows x 9 columns]

# %%
merged = top_tracks.merge(
    spotify,
    left_on=["track_name", "artist_name"],
    right_on=["song", "Artist(s)"],
    how="inner"
)

# %%
merged["release_year"] = pd.to_datetime(
    merged["Release Date"], errors="coerce"
).dt.year

# Categorical columns to one-hot encode
cat_cols = ["emotion", "Key", "Time signature", "Explicit"]

merged_dummies = pd.get_dummies(
    merged,
    columns=cat_cols,
    prefix=cat_cols,
    drop_first=False  
)

feature_cols = merged_dummies.select_dtypes(include=["int64", "float64"]).columns

feature_cols = feature_cols.drop([
    "user_id", "rank",
    "playcount", "playcount_norm",
    "total_scrobbles_x", "total_scrobbles_y", "total_scrobbles",
    "Similarity Score 1", "Similarity Score 2", "Similarity Score 3"
], errors="ignore")

dummy_cols = [
    c for c in feature_cols
    if c.startswith("emotion_")
    or c.startswith("Key_")
    or c.startswith("Time signature_")
    or c.startswith("Explicit_")
]

numeric_cols = [c for c in feature_cols if c not in dummy_cols]

# %%
# Out:
# Index(['Tempo', 'Popularity', 'Energy', 'Danceability', 'Positiveness',
#        'Speechiness', 'Liveness', 'Acousticness', 'Instrumentalness',
#        'Good for Party', 'Good for Work/Study',
#        'Good for Relaxation/Meditation', 'Good for Exercise',
#        'Good for Running', 'Good for Yoga/Stretching', 'Good for Driving',
#        'Good for Social Gatherings', 'Good for Morning Routine',
#        'release_year'],
#       dtype='object')

# %%
agg_stats = ["mean", "std", "min", "max", "median"]

user_num = (
    merged_dummies
      .groupby("user_id")[numeric_cols]
      .agg(agg_stats)
)

user_num.columns = [f"{feat}_{stat}" for feat, stat in user_num.columns]

user_cat = (
    merged_dummies
      .groupby("user_id")[dummy_cols]
      .mean()
)

# %%
user_features = (
    pd.concat([user_num, user_cat], axis=1)
      .reset_index()
)

user_features
# Out:
#        user_id  Tempo_mean  Tempo_std  Tempo_min  Tempo_max  Tempo_median  \
# 0            1  126.150000  23.680494         63        169         126.5
# 1           30  121.666667  24.960803         82        185         121.0
# 2           97  133.878788  29.945531         85        185         134.0
# 3          151  128.250000  27.509935         78        191         131.0
# 4          209  144.260870  35.615647         70        200         140.0
# ...        ...         ...        ...        ...        ...           ...
# 14058   478969  129.909091  30.339593         77        164         130.0
# 14059   479269  118.545455  33.331635         52        178         116.0
# 14060   479275  119.575758  28.743510         65        180         127.0
# 14061   479294  129.400000  29.831809         82        175         133.0
# 14062   479339  119.181818  36.099358         78        180         110.0
#
#        Popularity_mean  Popularity_std  Popularity_min  Popularity_max  ...  \
# 0            47.600000       16.125821              17              82  ...
# 1            48.000000       13.093414              14              76  ...
# 2            45.303030       15.222280              16              73  ...
# 3            48.250000       17.112657              18              83  ...
# 4            51.130435       15.743121              26              78  ...
# ...                ...             ...             ...             ...  ...
# 14058        60.000000       12.222929              40              80  ...
# 14059        42.318182       11.172584              10              64  ...
# 14060        59.575758       14.912307              28              86  ...
# 14061        46.900000       15.457582              10              69  ...
# 14062        67.000000       14.064139              47              90  ...
#
#        Good for Morning Routine_mean  Good for Morning Routine_std  \
# 0                           0.300000                      0.470162
# 1                           0.030303                      0.174078
# 2                           0.000000                      0.000000
# 3                           0.045455                      0.210707
# 4                           0.043478                      0.208514
# ...                              ...                           ...
# 14058                       0.090909                      0.301511
# 14059                       0.000000                      0.000000
# 14060                       0.030303                      0.174078
# 14061                       0.050000                      0.223607
# 14062                       0.000000                      0.000000
#
#        Good for Morning Routine_min  Good for Morning Routine_max  \
# 0                                 0                             1
# 1                                 0                             1
# 2                                 0                             0
# 3                                 0                             1
# 4                                 0                             1
# ...                             ...                           ...
# 14058                             0                             1
# 14059                             0                             0
# 14060                             0                             1
# 14061                             0                             1
# 14062                             0                             0
#
#        Good for Morning Routine_median  release_year_mean  release_year_std  \
# 0                                  0.0        2005.600000          5.639149
# 1                                  0.0        2001.428571          4.894117
# 2                                  0.0        2007.571429          3.207135
# 3                                  0.0        2004.666667          3.201562
# 4                                  0.0        1996.875000          8.675705
# ...                                ...                ...               ...
# 14058                              0.0        2017.500000          6.363961
# 14059                              0.0        2008.700000          9.055999
# 14060                              0.0        2008.666667          2.994945
# 14061                              0.0                NaN               NaN
# 14062                              0.0        2015.333333          4.618802
#
#        release_year_min  release_year_max  release_year_median
# 0                1996.0            2011.0               2007.0
# 1                1998.0            2011.0               2000.0
# 2                2003.0            2010.0               2009.0
# 3                2000.0            2008.0               2007.0
# 4                1982.0            2010.0               1994.0
# ...                 ...               ...                  ...
# 14058            2013.0            2022.0               2017.5
# 14059            2000.0            2024.0               2006.0
# 14060            2000.0            2011.0               2010.0
# 14061               NaN               NaN                  NaN
# 14062            2010.0            2018.0               2018.0
#
# [14063 rows x 96 columns]

# %%
genre_diversity = (
    merged
      .groupby("user_id")["Genre"]
      .nunique()
)

# %%
user_df = user_features.merge(
    genre_diversity.rename("genre_diversity"),
    on="user_id",
    how="inner"
)

threshold = user_df["genre_diversity"].median()

user_df["high_genre_diversity"] = (user_df["genre_diversity"] > threshold).astype(int)

user_df.drop(columns=["genre_diversity"], inplace=True)

user_df.to_csv("data/user_df.csv", index=False)
